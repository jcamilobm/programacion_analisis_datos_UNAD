# %% [markdown]
# <div align="center">
#
#   <b>Curso: Programación para el Análisis de Datos<span></b>
#
#   <b>Ejercicio 3: Gráficos científicos</b>
#
#   <b>Presentado por: Juan Camilo Betancourt Monsalve</b>
#
#   <b>Grupo: 30 </b>
#
#   <b>Código: 203008069
#
#   <b>Presentado a: Miguel Angel Vargas Valencia</b>
#
#   <img src="https://estudios.unad.edu.co/images/footer/logo-unad-acreditacion-min.png" alt="logo universidad UNAD">
#
#
#   <b>17/03/2024</b>
#
# </div>

# %% [markdown]
# # Resumen
#
# El objetivo de este notebook es desarrollar códigos para generar y visualizar gráficos en Python que faciliten la extracción de información de los datos utilizando librerías como matplotlib.
#
# **Palabras clave:** Visualización, Python, Matplotlib
#
# # Abstract
#
# The objective of this notebook is to develop code to generate and visualize graphs in Python that facilitate data extraction using libraries such as matplotlib.
#
# **Keywords:** Visualization, Python, Matplotlib

# %% [markdown]
# # Introducción
#
# La visualización de datos es una técnica de exploración importante para extraer información. Python ofrtece librerías como matplotlib que facilitan el proceso mediente:
#
# - Gráfico de regresiones: Definir funciones y graficar su dominicio.
# - Simulares nubes de dispersión de distirbuciones normales y uniformes para entender patrones.
# - Graficar en un solo gráfico para establecer comparaciones.

# %% [markdown]
# # Desarrollo

# %%
# Importar librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Gráfico 1:

# %% [markdown]
# Mostrar los puntos de dispersión del emparejamiento las
# siguientes listas:
#
# $$x= [13,14,15,16,17,18]$$
# $$y= [16,24,45,57,75,102]$$
#
# • Mostrar la función lineal 𝒇(𝒙) = 𝟏𝟕𝒙 − 𝟐𝟏𝟎. 𝟑𝟑𝟑𝟑 en el dominio
# [13,18].
#
# • Mostrar la función exponencial 𝒈(𝒙) = 𝟎. 𝟏𝟒𝟓𝟐 𝒆(𝟎.𝟑𝟔𝟗𝒙) en el
# dominio [13,18].
#
# • Mostrar la función logarítmica 𝒉(𝒙) = 𝟐𝟓𝟗. 𝟒𝟗 𝒍𝒏(𝒙) − 𝟔𝟓𝟔. 𝟒𝟔 en el dominio [13,18].
#
# • Los objetos mostrados deben tener colores diferentes.
#
# • La línea de la función logarítmica debe ser punteada.
#
# • En los ejes deben visualizarse los números.
#
# • Asigne un nombre (label) a cada objeto e imprima la legenda
# que los identifique en la gráfica.
#
# • Asigne nombres a los ejes de la gráfica.
#
# • Asigne un título a la gráfica.
#
# • Tenga en cuenta que los nombres que decida utilizar le serán de
# ayuda para presentar las conclusiones que usted obtenga del
# ejercicio.

# %%
# Defino puntos de dispersión
x = [13, 14, 15, 16, 17, 18]
y = [16, 24, 45, 57, 75, 102]

#Defino funciones
def f(x):
    return 17 * x - 210.3333

def g(x):
    return 0.1452 * np.exp(0.369 * x)

def h(x):
    return 259.49 * np.log(x) - 656.46

# Crear un conjunto de valores x en el dominio [13, 18] partidos en 100
x_v = np.linspace(13, 18, 100)

# configuro la figura
plt.figure(figsize=(10,6))
plt.xlabel("x")
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Puntos de dispersión')

# Trazo los puntos de dispersión
plt.scatter(x,y,label='Datos de dispersión', color='red')

plt.plot(x_v, f(x_v), label='$f(x) := 17x - 210.3333$',color='pink')

plt.plot(x_v, g(x_v), label='$g(x) := 0.1452 * e^{0.369x}$',color="green")

plt.plot(x_v, h(x_v), label='$h(x):= 259.49 * log(x) - 656.46$' , linestyle="--",color='blue')


# Muestro la leyenda
plt.legend()

# Muestro el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# **Análisis del gráfico 1**

# %% [markdown]
# - Python permite analizar graficas en una sola figura para sacar comparaciones valiosas.
# - Las graficas son las regresiones de los puntos.
#
# - La mejor regresión es la lineal según el error cuadrático medio.

# %%
# Calcular el error cuadrático medio (ECM)

def ecm(y_observado, y_prediccion):
    return  np.mean((y_observado - y_prediccion)**2)

ecm_f = ecm( np.array(y), np.array([f(x) for x in x]) )
ecm_g = ecm( np.array(y), np.array([g(x) for x in x]) )
ecm_h = ecm( np.array(y), np.array([h(x) for x in x]) )

print("Error cuadrático medio f(x): ", ecm_f  )
print("Error cuadrático medio g(x): ", ecm_g  )
print("Error cuadrático medio h(x): ", ecm_h  )
# Out:
# Error cuadrático medio f(x):  19.555555556666665
# Error cuadrático medio g(x):  29.477954745888155
# Error cuadrático medio h(x):  31.488153489140966

# %% [markdown]
# El Error cuadrático medio indica que la función lineal f(x) predice mejor los resultados.

# %% [markdown]
# # Gráfico 2:
# Construya los códigos necesarios para:

# %% [markdown]
# - Generar 4 listas aleatorias de 700 muestras (revise la
# documentación de numpy.random):
#
#   - x1 con distribución normal de media 5 y desviación
#   estándar 0.1.
#
#   - y1 con distribución normal de media 7 y desviación estándar 0.1.
#  -  x2 con distribución uniforme entre el valor mínimo de x1 y
# el valor máximo de x1.
#
#   - y2 con distribución uniforme entre el valor mínimo de y1 y
# el valor máximo de y1.
#
# - Graficar en un mismo plot nubes de dispersión de los pares de
# puntos que se forman con (x1, y1) y (x2, y2).
#
# - La nube de puntos (x2, y2) debe visualizarse sobre la nube de
# (x1, y1).
#
# - Anexe los títulos y legendas necesarios para poder citar y
# explicar realizar el análisis del gráfico obtenido y las
# conclusiones.

# %%
# Definir los parámetros de media y desviación estándar
media_x1 = 5
desviacion_estandar_x1 = 0.1

media_y1 = 7
desviacion_estandar_y1 = 0.1

# Generar las listas aleatorias
# loc: media o valor esperado
x1 = np.random.normal(loc=media_x1, scale=desviacion_estandar_x1, size=700)
y1 = np.random.normal(loc=media_y1, scale=desviacion_estandar_y1, size=700)

# Imprimir
print("x1:", x1[:5])
print("")
print("y1:", y1[:5])

# Hallar valores mínimos

min_x1 ,max_x1 = x1.min() , x1.max()
min_y1 , max_y1 = y1.min() , y1.max()

print(f'Rango de x1: {min_x1} a {max_x1}')
print(f'Rango de  y1: {min_y1} a {max_y1}')
# Out:
# x1: [4.82355059 5.03814453 4.98584169 4.95102873 4.9980132 ]
#
# y1: [7.10659182 7.16300815 6.9321578  7.21070928 6.95831498]
# Rango de x1: 4.651036959846063 a 5.267845094035937
# Rango de  y1: 6.716648466157094 a 7.306288705197545

# %%
# Generar un array con distribución uniforme
x2 =  np.random.uniform(low=min_x1, high=max_x1, size=700)
y2 =  np.random.uniform(low=min_y1, high=max_y1, size=700)
# Imprimir
print("x2:", x2[:5])
print("")
print("y2:", y2[:5])
# Out:
# x2: [5.08224667 5.11806164 4.71994421 4.71053445 4.99010744]
#
# y2: [7.18475307 7.07347613 6.94693284 7.11897162 6.76027028]

# %% [markdown]
# - Graficar en un mismo plot nubes de dispersión de los pares de
# puntos que se forman con (x1, y1) y (x2, y2).

# %%
# Graficar las nubes de dispersión
plt.scatter(x1, y1, color='blue',alpha=0.4,  label='Dist.Normal')
plt.scatter(x2, y2, color='red', alpha=0.6, label='Dist.Uniforme')

# Etiquetas y título del gráfico
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Nubes de Dispersión')

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del gráfico 2**
#
# - La distribución normal aglomera los puntos alrededor de la media , por otro lado la uniforme los distribuye en todo el espacio.
# - Python permite hacer simulaciones para notar patrones en los datos.

# %% [markdown]
# # Gráficos 3:

# %% [markdown]
# Genere las siguientes dos visualizaciones que se proponen
# a continuación:
#
# - Cargue en la variable df1 el conjunto de datos que se presentan
# en el archivo Excel, Anexo 1 - Base de Datos Excel.xlsx, que se
# encuentra en la carpeta de la Tarea 1 - Fundamentos de
# programación científica con Python.
#
# - En una misma gráfica presente 2 histogramas de las variables
# Tiempo motor ON y Tiempo en Movimiento, respectivamente.
# Deben ser lo suficientemente transparentes, para poder ver
# ambas al tiempo. (Revise la documentación de la función
# matplotlib.pyplot.hist).
#
# - En otra gráfica, genere el gráfico de dispersión que se obtiene
# de emparejar los valores de Tiempo motor ON y Tiempo en
# Movimiento.
#
# - Anexe los títulos y legendas necesarios en ambos gráficos para
# poder citar y explicar el análisis de los gráficos obtenidos y las
# conclusiones.

# %%
# Cargar conjunto de datos de los servicios de ambulancias:

url = 'https://github.com/jcamilobm/programacion_analisis_datos/blob/main/tarea_1/Anexo%201%20-%20Base%20de%20Datos%20EXCEL.xlsx?raw=true'
df1 = pd.read_excel( url, sheet_name=1, index_col=0 , skiprows=3 )
df1.head(2)
# Out:
#          Empresa Turno  Día de la semana Experiencia del conductor  \
# Servicio
# 1            TAC     D                 5              Principiante
# 2            TAD     N                 4              Principiante
#
#           Formación del Paramédico Nivel del Paramédico  \
# Servicio
# 1                                4                    I
# 2                                3                    B
#
#           Cantidad de atenciones  Distancia recorrida (Km)  \
# Servicio
# 1                              8                      78.4
# 2                              5                      46.2
#
#           Velocidad máxima (Km/h)  Consumo de combustible (Galones)  \
# Servicio
# 1                              82                               3.1
# 2                              89                               1.9
#
#           Tiempo en Movimiento (h)  Tiempo motor ON (h)
# Servicio
# 1                              2.8                 3.08
# ...

# %%
# Crear dos histogramas en una misma gráfica
plt.hist(df1['Tiempo motor ON (h)'], bins=20, alpha=0.5, label='Tiempo motor ON ')  # Primer histograma
plt.hist(df1['Tiempo en Movimiento (h)'], bins=20, alpha=0.5, label='Tiempo en Movimiento')  # Segundo histograma

# Añadir etiquetas y título al gráfico
plt.xlabel('Tiempo(h)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Tiempo motor ON y Tiempo en Movimiento ')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# - Tiempo en Movimiento (h): Cantidad total de horas que la ambulancia se encontraba en movimiento durante el servicio (captado por GPS).
#
# - Tiempo motor ON (h): Cantidad total de horas que la ambulancia mantuvo el motor encendido, así no se encontrara en movimiento (captado por sensor de encendido).

# %% [markdown]
# **Análisis gráfico 3.1 de histogramas**
#
# - El tiempo de motor encendido y el tiempo en movimiento tienen una distribución normal, tienen simetría alrededor de su media.
# - La varianza de la distribución  del tiempo del motor encendido es mayor ya que es más ancha la gráfica.
# - El tiempo de motor encendido presenta una distribución mosocúrtica , por otro lado el tiempo en movimiento es leptocúrtica.
# -  El tiempo de motor encendido presenta más valores atípicos sobretodo al lado derecho.
# - Se nota que las ambulancias pasan buen tiempo paradas con el motor encendido tal vez sea por la urgencia de recoger al herido y arrancar sin esperar a prender el motor de nuevo. Además, por norma la inspección del vehículo se hace con el motor encendido.

# %%
# Generar el gráfico de dispersión con colores distintos
plt.scatter(df1['Tiempo motor ON (h)'], df1['Tiempo en Movimiento (h)'], alpha=0.5, c='violet')  # Puntos en azul

# Etiquetas y título del gráfico
plt.xlabel('Tiempo motor ON (h)')
plt.ylabel('Tiempo en Movimiento (h)')
plt.title('Gráfico  Tiempo en Movimiento vs Dispersión Tiempo motor ON ')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Análisis de resultados gráfica 3.2
#
# - Según la gráfica de dispersión a menores tiempo del motor encendido hay más casos irregulares donde la ambulancia sigue en movimiento. Por ejemplo, con 1h encencido el motor tener casi 2:30h de movimiento.

# %% [markdown]
# # Conclusiones

# %% [markdown]
# - Python permite analizar graficas en una sola figura para sacar comparaciones valiosas.
# - La  gráfica 1 representa las regresiones de los puntos a partir de un modelo lineal, uno exponencial y otro logaritmo.
# - Según el error cuadrático medio calculado para cada regresión de las funciones d ela gráfica 1; el modelo lineal tiene un menor margen de error.
#
# - Según la gráfica 2 la distribución normal aglomera los puntos alrededor de la media , por otro lado la uniforme los distribuye en todo el espacio.
#
# - Python permite hacer simulaciones para notar patrones en los datos.
#
# - Según la gráfica 3.1 de histogramas el tiempo de motor encendido y el tiempo en movimiento tienen una distribución normal, tienen simetría alrededor de su media.
# - Según la gráfica 3.1 de histogramas la varianza de la distribución  del tiempo del motor encendido es mayor ya que es más ancha la gráfica.
#
# - Según la gráfica 3.1 de histogramas el tiempo de motor encendido presenta una distribución mosocúrtica , por otro lado el tiempo en movimiento es leptocúrtica.
# - Según la gráfica 3.1 de histogramas  el tiempo de motor encendido presenta más valores atípicos sobretodo al lado derecho.
#
# - Según la gráfica 3.1 de histogramas , las ambulancias pasan buen tiempo paradas con el motor encendido tal vez sea por la urgencia de recoger al herido y arrancar sin esperar a prender el motor de nuevo. Además, por norma la inspección del vehículo se hace con el motor encendido.
#
# - Según la gráfica 3.2 de dispersión a menores tiempo del motor encendido hay más casos irregulares donde la ambulancia sigue en movimiento. Por ejemplo, con 1h encencido el motor tener casi 2:30h de movimiento.

# %% [markdown]
# # Bibliografía

# %% [markdown]
# Kane, F. (2017). Hands-On Data Science and Python Machine
# Learning. Packt Publishing. (pp. 56-62)
